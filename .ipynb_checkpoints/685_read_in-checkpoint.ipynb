# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from collections import defaultdict

# %%
# example of intended df style
changes = pd.DataFrame(columns=('Hero', 'Text', 'num_buffs', 'num_nerfs'))
rows_list = []
rows_list.append({'hero_name': 'Abaddon', 'patch_text': ["Mist Coil cooldown reduced from 5 to 4.5", "Borrowed Time Aghanim's Scepter damage redirection increased from 35% to 50%"], 'num_buffs': 2, 'num_nerfs': 0})
rows_list.append({'hero_name': 'Alchemist', 'patch_text': ["Acid Spray damage increased from 12/16/20/24 to 15/20/25/30", "Acid Spray damage increased from 12/16/20/24 to 15/20/25/30"], 'num_buffs': 2, 'num_nerfs': 0})
pd.DataFrame(rows_list)
# Out:
#    hero_name  num_buffs  num_nerfs  \
# 0    Abaddon          2          0
# 1  Alchemist          2          0
#
#                                           patch_text
# 0  [Mist Coil cooldown reduced from 5 to 4.5, Bor...
# 1  [Acid Spray damage increased from 12/16/20/24 ...

# %%
# SCRAPE FOR HERO NAME SET

r_heroes = requests.get('http://www.dota2.com/heroes/')
soup_heroes = BeautifulSoup(r_heroes.content, 'html.parser')
hero_name_set = set()
for column in soup_heroes.findAll('div', {'class': 'heroIcons'}):
    for a_tag in column.findAll('a'):
        hero_name_set.add(a_tag['href'].split('/')[-2].replace('_', ' '))

hero_name_set.remove('Natures Prophet')
hero_name_set.add("Nature's Prophet") # dota2.com doesn't include apostrophe

# %%
def wiki_query(page, hero_name_set):
    '''
    INPUT: string
    OUTPUT: list of lists of strings
    '''
    r = requests.get('https://dota2.gamepedia.com/{0}'.format(page))
    soup = BeautifulSoup(r.content, 'html.parser')

    hero_change_dict = defaultdict(list)
    for ul in soup.find('div', {'id': 'mw-content-text'}).find('div', recursive=False).findAll('ul', recursive=False):
        try:
            li = ul.find('li')
            if li.find('a')['title'] in hero_name_set:
                for sub_ul in li.findAll('ul', recursive=False):
                    for sub_li in sub_ul.findAll('li', recursive=False):
                        hero_change_dict[li.find('a')['title']].append(sub_li.text.strip())
        except:
            continue

    return hero_change_dict

# %%
hero_change_dict = wiki_query('September_24,_2015_Patch', hero_name_set)

# %%
hero_change_dict['Chaos Knight']
# Out:
# [u"Chaos Strike now lowers the target's armor by 5 for 8 seconds whenever it crits \n\nApplies before the damage happens, like  Desolator. Can be applied by illusions, but multiple instances do not stack. Only triggers when critical strike",
#  u'Chaos Strike critical damage reduced from 150/200/250/300% to 125/175/225/275%']

# %%
# BUILD DATA FRAME
# redo this to use dictionary?

heroes = []
change_text = []
for hero, text_list in hero_change_dict.iteritems():
    heroes.append(hero)
    change_text.append(text_list)
df = pd.DataFrame({'hero': heroes, 'text': change_text})

# %%
df.loc[20]['text']
# Out:
# [u'Blink distance rescaled from 1000/1075/1150/1150 to 925/1000/1075/1150',
#  u'Mana Void stun rescaled from 0.1/0.2/0.3 to 0.15']

# %%
changed_heroes_685 = set(df.hero.values)

# %%
# FIND HEROES NOT CHANGED IN PATCH

untouched_heroes = []
for hero in hero_name_set:
    if not hero in changed_heroes_685:
        untouched_heroes.append(hero)

# %%
# ADD UNCHANGED HEROES TO DF

df_all = pd.concat([df, pd.DataFrame({'hero':untouched_heroes, 'text':[[]]*len(untouched_heroes)})])

# %%
df_all.sort('hero', inplace=True)
df_all.reset_index(inplace=True)
df_all.drop('index', axis=1, inplace=True)

# %%
# USED FOR MANUAL DATA ENTRY
# df_all.to_csv('hero_table_685.csv')
# df_xl = pd.read_csv('hero_table_685_xl.csv')

# %%
df_changes = pd.concat([df_all, df_xl[['num_buffs', 'num_nerfs', 'change_type']]], axis=1)

# %%
df_changes['change_type'] = df_changes['change_type'].apply(lambda x: x.replace('[', '').replace(']', '').split(','))
df_changes['change_type'] = df_changes['change_type'].apply(lambda x: [int(num.strip()) for num in x] if len(x[0]) > 0 else [])

# %%
df_changes.head(6)
# Out:
#                  hero                                               text  \
# 0             Abaddon  [Mist Coil cooldown reduced from 5 to 4.5, Bor...
# 1           Alchemist  [Acid Spray damage increased from 12/16/20/24 ...
# 2  Ancient Apparition  [Cold Feet cast range increased from 700 to 70...
# 3           Anti-Mage  [Blink distance rescaled from 1000/1075/1150/1...
# 4          Arc Warden        [Spark Wraith cooldown reduced from 7 to 4]
# 5                 Axe                                                 []
#
#    num_buffs  num_nerfs change_type
# 0          2          0      [1, 1]
# 1          2          0      [1, 1]
# 2          1          0         [1]
# 3          0          2    [-1, -1]
# 4          1          0         [1]
# 5          0          0          []

# %%
# Pudge and Shadow Shaman have an additional fix listed on wiki
df_changes['change_type'][69] = [1,1,1]
df_changes['change_type'][78] = [1,1,1]
# Out:
# /anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from IPython.kernel.zmq import kernelapp as app
# /anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
import json
with open('../dota2-database/json/abilities.json') as f:
    abi_json = json.load(f)

# %%
ability_set = set(ability['localizedName'] for ability in abi_json)
ability_set.remove('')

# %%
import json
with open('../dota2-database/json/heroes.json') as f:
    hero_json = json.load(f)

# %%
hero_json_set = set(hero['localizedName'] for hero in hero_json)

# %%
hero_name_set - hero_json_set
# Out:
# {u'Arc Warden', u'Oracle', u'Techies', u'Winter Wyvern'}

# %%
hero_json_set - hero_name_set
# Out:
# set()

# %%
def remove_abi_names(changelist):
    changes_trimmed = []
    for i, item in enumerate(changelist):
        changes_trimmed.append(item)
        for abi in ability_set:
            item = item.replace(abi, '').strip()
            changes_trimmed[i] = item
    return changes_trimmed

# %%
df_changes['text_no_abi'] = df_changes['text'].apply(remove_abi_names)

# %%
df_changes
# Out:
#                    hero                                               text  \
# 0               Abaddon  [Mist Coil cooldown reduced from 5 to 4.5, Bor...
# 1             Alchemist  [Acid Spray damage increased from 12/16/20/24 ...
# 2    Ancient Apparition  [Cold Feet cast range increased from 700 to 70...
# 3             Anti-Mage  [Blink distance rescaled from 1000/1075/1150/1...
# 4            Arc Warden        [Spark Wraith cooldown reduced from 7 to 4]
# 5                   Axe                                                 []
# 6                  Bane  [Enfeeble cooldown reduced from 10 to 8, Brain...
# 7              Batrider  [Flamebreak damage over time reduced from 50 p...
# 8           Beastmaster                                                 []
# 9           Bloodseeker  [Thirst scaling changed from 100%->25% to 75%-...
# 10        Bounty Hunter  [Track now provides vision only of the target ...
# 11           Brewmaster  [Primal Split Storm's Dispel Magic area of eff...
# 12          Bristleback  [Bristleback passive  Quill Spray damage thres...
# 13          Broodmother                                                 []
# 14    Centaur Warrunner  [Return strength as bonus damage increased fro...
# 15         Chaos Knight  [Chaos Strike now lowers the target's armor by...
# 16                 Chen  [Penitence slow/damage amplification increased...
# 17               Clinkz  [Strafe cooldown reduced from 45/40/35/30 to 4...
# 18            Clockwerk                                                 []
# 19       Crystal Maiden      [Crystal Nova cooldown reduced from 15 to 13]
# 20            Dark Seer                   [Base intelligence reduced by 2]
# 21               Dazzle  [Poison Touch mana cost reduced from 100/115/1...
# 22        Death Prophet  [Exorcism spirits increased from 6/13/21 to 8/...
# 23            Disruptor  [Thunder Strike cooldown reduced from 16 to 12...
# 24                 Doom  [Scorched Earth damage/heal increased from 12/...
# 25        Dragon Knight  [Breathe Fire debuff duration increased from 8...
# 26          Drow Ranger  [Precision Aura bonus damage increased from 18...
# 27         Earth Spirit  [Stone Remnant is now placed in front of you w...
# 28          Earthshaker  [Fissure damage reduced from 125/175/225/275 t...
# 29          Elder Titan  [Echo Stomp area of effect increased from 475 ...
# ..                  ...                                                ...
# 81              Slardar  [Sprint now provides phased movement, Sprint c...
# 82                Slark                                                 []
# 83               Sniper   [Shrapnel delay reduced from 1.4 to 1.2 seconds]
# 84              Spectre  [Desolate now works on non-hero units if they ...
# 85       Spirit Breaker       [Greater Bash now uses pseudo random chance]
# 86         Storm Spirit  [Static Remnant mana cost increased from 70/80...
# 87                 Sven  [Base intelligence increased by 2, Great Cleav...
# 88              Techies  [Techies' mines are no longer triggered when d...
# 89     Templar Assassin                                                 []
# 90          Terrorblade  [Temporarily removed from Captains Mode, Refle...
# 91           Tidehunter  [Gush armor reduction increased from 2/3/4/5 t...
# 92            Timbersaw      [Whirling Death cooldown reduced from 8 to 6]
# 93               Tinker  [Rearm channel time reduced from 3/2/1 to 3/1....
# 94                 Tiny  [Base strength increased from 24 to 26, Base i...
# 95     Treant Protector  [Leech Seed mana cost reduced from 140 to 100/...
# 96        Troll Warlord  [Fervor attack speed per stack increased from ...
# 97                 Tusk  [Ice Shards mana cost increased from 90 to 100...
# 98              Undying  [Aghanim's Scepter no longer improves Flesh Go...
# 99                 Ursa  [Strength gain reduced from 2.9 to 2.7, Earths...
# 100     Vengeful Spirit  [Agility gain increased from 2.8 to 3.3, Base ...
# 101          Venomancer  [Poison Sting damage increased from 5/10/15/20...
# 102               Viper  [Agility growth increased from 2.5 to 2.9, Cor...
# 103              Visage  [Familiar's Stone Form area of effect increase...
# 104             Warlock       [Golems can no longer be destroyed by Purge]
# 105              Weaver  [The Swarm mana cost rescaled from 100 to 70/8...
# 106          Windranger                                                 []
# 107       Winter Wyvern  [Winter's Curse no longer affects Spell Immune...
# 108        Witch Doctor  [Death Ward damage increased from 60/90/120 to...
# 109         Wraith King  [Base damage increased by 7, Vampiric Aura doe...
# 110                Zeus                                                 []
#
#      num_buffs  num_nerfs                      change_type  \
# 0            2          0                           [1, 1]
# 1            2          0                           [1, 1]
# 2            1          0                              [1]
# 3            0          2                         [-1, -1]
# 4            1          0                              [1]
# 5            0          0                               []
# 6            3          0                        [1, 1, 1]
# 7            2          1                       [-1, 1, 1]
# 8            0          0                               []
# 9            0          2                         [-1, -1]
# 10           0          2                         [-1, -1]
# 11           3          0                        [1, 1, 1]
# 12           1          0                              [1]
# 13           0          0                               []
# 14           1          0                              [1]
# 15           1          1                          [1, -1]
# 16           3          0                        [1, 1, 1]
# 17           1          0                              [1]
# 18           0          0                               []
# 19           1          0                              [1]
# 20           0          1                             [-1]
# 21           1          0                              [1]
# 22           1          0                              [1]
# 23           1          1                          [1, -1]
# 24           2          0                           [1, 1]
# 25           1          0                              [1]
# 26           2          0                           [1, 1]
# 27           1          0                              [1]
# 28           0          1                             [-1]
# 29           4          0                     [1, 1, 1, 1]
# ..         ...        ...                              ...
# 81           2          1                       [1, 1, -1]
# 82           0          0                               []
# 83           1          0                              [1]
# 84           2          0                           [1, 1]
# 85           0          1                             [-1]
# 86           0          3                     [-1, -1, -1]
# 87           2          0                           [1, 1]
# 88           2          6   [-1, -1, -1, 1, -1, 1, -1, -1]
# 89           0          0                               []
# 90           5          4  [-1, 1, -1, -1, -1, 1, 1, 1, 1]
# 91           1          0                              [1]
# 92           1          0                              [1]
# 93           1          0                              [1]
# 94           2          0                           [1, 1]
# 95           1          0                              [1]
# 96           1          0                              [1]
# 97           1          3                  [-1, -1, -1, 1]
# 98           2          3               [-1, 1, -1, -1, 1]
# 99           2          2                   [-1, 1, -1, 1]
# 100          2          0                           [1, 1]
# 101          4          0                     [1, 1, 1, 1]
# 102          1          1                          [1, -1]
# 103          1          0                              [1]
# 104          1          0                              [1]
# 105          2          0                           [1, 1]
# 106          0          0                               []
# 107          0          1                             [-1]
# 108          1          1                          [1, -1]
# 109          4          0                     [1, 1, 1, 1]
# 110          0          0                               []
#
#                                            text_no_abi
# 0    [cooldown reduced from 5 to 4.5, Aghanim's Sce...
# 1    [damage increased from 12/16/20/24 to 15/20/25...
# 2    [cast range increased from 700 to 700/800/900/...
# 3    [distance rescaled from 1000/1075/1150/1150 to...
# 4          [Spark Wraith cooldown reduced from 7 to 4]
# 5                                                   []
# 6    [cooldown reduced from 10 to 8, mana cost redu...
# 7    [damage over time reduced from 50 per second t...
# 8                                                   []
# 9    [scaling changed from 100%->25% to 75%->25%, h...
# 10   [now provides vision only of the target rather...
# 11   [Storm's Dispel Magic area of effect increased...
# 12   [passive   damage threshold reduced from 250 t...
# 13                                                  []
# 14   [strength as bonus damage increased from 26/34...
# 15   [now lowers the target's armor by 5 for 8 seco...
# 16   [slow/damage amplification increased from 14/1...
# 17   [cooldown reduced from 45/40/35/30 to 40/35/30...
# 18                                                  []
# 19                    [cooldown reduced from 15 to 13]
# 20                    [Base intelligence reduced by 2]
# 21     [mana cost reduced from 100/115/130/145 to 100]
# 22         [spirits increased from 6/13/21 to 8/14/21]
# 23   [cooldown reduced from 16 to 12/11/10/9, now o...
# 24   [damage/heal increased from 12/18/24/30 to 12/...
# 25    [debuff duration increased from 8 to 11 seconds]
# 26   [bonus damage increased from 18/24/30/36% to 2...
# 27   [is now placed in front of you when double-cli...
# 28   [damage reduced from 125/175/225/275 to 110/16...
# 29   [area of effect increased from 475 to 500, man...
# ..                                                 ...
# 81   [now provides phased movement, cooldown reduce...
# 82                                                  []
# 83             [delay reduced from 1.4 to 1.2 seconds]
# 84   [now works on non-hero units if they are alone...
# 85            [Greater  now uses pseudo random chance]
# 86   [mana cost increased from 70/80/90/100 to 100,...
# 87   [Base intelligence increased by 2, damage incr...
# 88   [Techies' mines are no longer triggered when d...
# 89                                                  []
# 90   [Temporarily removed from Captains Mode, now a...
# 91   [armor reduction increased from 2/3/4/5 to 3/4...
# 92                      [cooldown reduced from 8 to 6]
# 93     [channel time reduced from 3/2/1 to 3/1.5/0.75]
# 94   [Base strength increased from 24 to 26, Base i...
# 95     [mana cost reduced from 140 to 100/110/120/130]
# 96   [attack speed per stack increased from 16/22/2...
# 97   [mana cost increased from 90 to 100/105/110/11...
# 98   [Aghanim's Scepter no longer improves \n\nPrev...
# 99   [Strength gain reduced from 2.9 to 2.7, cooldo...
# 100  [Agility gain increased from 2.8 to 3.3, Base ...
# 101  [damage increased from 5/10/15/20 to 6/12/18/2...
# 102  [Agility growth increased from 2.5 to 2.9, slo...
# 103  [Familiar's Stone Form area of effect increase...
# 104       [Golems can no longer be destroyed by Purge]
# 105  [mana cost rescaled from 100 to 70/80/90/100, ...
# 106                                                 []
# 107  [Winter's Curse no longer affects Spell Immune...
# 108  [damage increased from 60/90/120 to 60/105/150...
# 109  [Base damage increased by 7, does not show the...
# 110                                                 []
#
# [111 rows x 6 columns]

# %%
df_changes.to_csv('patch_685_processed.csv')
